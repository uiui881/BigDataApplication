# %%
import openpyxl
import csv

# %%
f = open('channel_info.csv', 'r', encoding='utf-8',errors='ignore')

# %%
rdr = csv.reader(f);

# %%
member=[]
i=0
for line in rdr :
    i+=1
    member.append(line)
    print(line)
#member.append(line)
f.close()
# Out:
# ['ID', 'OPEN_DATE', 'CATEGORY_ID', 'SUBSCRIBERS', 'AVERAGE_VIEWS', 'TOTAL_VIEWS', 'VIDEOS', 'AGENT_ID', 'LANGUAGE']
# ['1', '2011-08-22', '3', '16400000', '5890700', '3097000000', '268', '12', '2']
# ['2', '2010-10-03', '3', '14300000', '34999600', '7995999999', '90', '4', '1']
# ['3', '2016-05-18', '8', '13800000', '153700', '4574000000', '389', 'null', '2']
# ['4', '2014-01-31', '9', '11000000', '15500', '5794900', '141', 'null', '3']
# ['5', '2012-11-16', '8', '10200000', '1273800', '3128000000', '901', 'null', '1']
# ['6', '2016-05-04', '9', '9310000', '49700', '3990999999', '1507', 'null', '2']
# ['7', '2015-09-25', '9', '7860000', '137600', '3195000000', '1593', 'null', '2']
# ['8', '2016-05-01', '9', '7760000', '2052000', '3397000000', '912', '2', '1']
# ['9', '2016-10-10', '1', '6800000', '198100', '1506000000', '274', 'null', '1']
# ['10', '2016-03-02', '9', '6790000', '524800', '2098000000', '895', '1', '4']
# ...

# %%
ff = open('channel_info.txt','w');
for line in member:
    str= "insert into channel_info('channel_id','opendate','category_id', 'subscriber', 'avg_view','all_view','video_num','agent_id','language_id') values("+line[0]+", "+line[1]+", "+line[2]+", "+line[3]+", "+line[4]+", "+line[5]+", "+line[6]+", "+line[7]+", "+line[8]+" );";
    print(str);
    ff.write(str);
    ff.write("\n");
  

ff.close()
# Out:
# insert into channel_info('channel_id','opendate','category_id', 'subscriber', 'avg_view','all_view','video_num','agent_id','language_id') values(ID, OPEN_DATE, CATEGORY_ID, SUBSCRIBERS, AVERAGE_VIEWS, TOTAL_VIEWS, VIDEOS, AGENT_ID, LANGUAGE );
# insert into channel_info('channel_id','opendate','category_id', 'subscriber', 'avg_view','all_view','video_num','agent_id','language_id') values(1, 2011-08-22, 3, 16400000, 5890700, 3097000000, 268, 12, 2 );
# insert into channel_info('channel_id','opendate','category_id', 'subscriber', 'avg_view','all_view','video_num','agent_id','language_id') values(2, 2010-10-03, 3, 14300000, 34999600, 7995999999, 90, 4, 1 );
# insert into channel_info('channel_id','opendate','category_id', 'subscriber', 'avg_view','all_view','video_num','agent_id','language_id') values(3, 2016-05-18, 8, 13800000, 153700, 4574000000, 389, null, 2 );
# ...
